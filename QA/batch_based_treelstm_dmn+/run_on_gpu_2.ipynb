# %%
# !nvidia-smi
# Out:
# Mon Jul 30 09:12:22 2018
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 384.111                Driver Version: 384.111                   |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 108...  Off  | 00000000:05:00.0 Off |                  N/A |
# |  0%   48C    P0    54W / 250W |      0MiB / 11170MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce GTX 108...  Off  | 00000000:09:00.0 Off |                  N/A |
# |  0%   43C    P5    28W / 250W |      0MiB / 11172MiB |      3%      Default |
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0 python3 untitled.py
# Out:
# word_idx: tensor([  7,  31,   4,  ...,   1,   3,   4], device='cuda:0')
# word_idx: tensor([ 18,  18,  11,  ...,  22,  22,  11], device='cuda:0')
# inputs: torch.Size([1, 2859, 80])
# child_c: torch.Size([1, 2859, 80])
# child_h: torch.Size([1, 2859, 80])
# word_idx: tensor([  5,   9,  25,  ...,  21,   5,   9], device='cuda:0')
# inputs: torch.Size([1, 5115, 80])
# child_c: torch.Size([2, 5115, 80])
# child_h: torch.Size([2, 5115, 80])
# word_idx: tensor([ 30,  30,  14,  ...,  30,  14,  23], device='cuda:0')
# inputs: torch.Size([1, 2001, 80])
# child_c: torch.Size([3, 2001, 80])
# child_h: torch.Size([3, 2001, 80])
# word_idx: tensor([ 26,  17,  24,  ...,   8,  14,   8], device='cuda:0')
# inputs: torch.Size([1, 5821, 80])
# child_c: torch.Size([2, 5821, 80])
# child_h: torch.Size([2, 5821, 80])
# word_idx: tensor([ 32,  32,  30,  30,  30,  32,  32,  30,  32,  32,  32,  30,
#          30,  30,  32,  30,  30,  32,  32,  30,  30,  32,  30,  30,
# ...

# %%
! python3 parse_tree.py > parser_log.txt 2>&1

# %%
! python3 untitled.py
# Out:
# ^C

# %%
import logging
def use_logging(func):
    
    def wrapper(*args, **kwargs):
        logging.warning("%s is running" % func.__name__)
        return func(*args, **kwargs)
    return wrapper

@use_logging
def bar():
    print('I am bar')
    
# bar = use_logging(bar)
bar()
# Out:
# WARNING:root:bar is running
# I am bar
