# %%
from keras.models import Sequential
from keras.layers.recurrent import LSTM
from keras.layers import Dense, Dropout, Activation
from keras.layers import Dense
import keras
# Out:
# /opt/anaconda3/envs/python2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
from keras import backend as K
from datetime import datetime
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from pandas import DataFrame
np.random.seed(42)
from tensorflow import set_random_seed
set_random_seed(2)
import warnings
warnings.filterwarnings("ignore")
import os
os.environ['PYTHONHASHSEED'] = '0'
import tensorflow as tf
session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, 
                              inter_op_parallelism_threads=1)
tf.set_random_seed(1234)

sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
K.set_session(sess)

# %%
# 设置图片大小
from pylab import rcParams
rcParams['figure.figsize'] = 20, 10

# %%
# 导入原始数据，获取数据，还原一阶差分
data = pd.read_csv('../df_money.csv', parse_dates = True, index_col=0)
data = data[21:]
data.head()
# Out:
#             scaled_money
# data
# 2014-01-22     99.547680
# 2014-01-23     99.972145
# 2014-01-24     84.135260
# 2014-01-25     18.354088
# 2014-01-26    100.000000

# %% [markdown]
# 测试集为[805:],所以需要的原始数组为[804:],这样对应位置相加就能还原为差分前的数列

# %%
before_diff = data.scaled_money[804:]

# %%
# 导入之前清理完成的数据
reframed = pd.read_csv('../bank_after_clean_20.csv', parse_dates = True, index_col=0)
reframed.head(5)
# Out:
#             count  week_number  weekday  is_quarter_end  holiday  var1(t-20)  \
# data
# 2014-01-12      4            6        1               0        0         NaN
# 2014-01-13     13            0        0               0        0         NaN
# 2014-01-14     11            1        0               0        0         NaN
# 2014-01-15     12            2        0               0        0         NaN
# 2014-01-16     12            3        0               0        0         NaN
#
#             var1(t-19)  var1(t-18)  var1(t-17)  var1(t-16)   ...     \
# data                                                         ...
# 2014-01-12         NaN         NaN         NaN         NaN   ...
# 2014-01-13         NaN         NaN         NaN         NaN   ...
# 2014-01-14         NaN         NaN         NaN         NaN   ...
# 2014-01-15         NaN         NaN         NaN         NaN   ...
# 2014-01-16         NaN         NaN         NaN         NaN   ...
#
#             var1(t-9)  var1(t-8)  var1(t-7)  var1(t-6)  var1(t-5)  var1(t-4)  \
# data
# 2014-01-12        NaN        NaN        NaN        NaN        NaN        NaN
# 2014-01-13        NaN        NaN        NaN        NaN        NaN        NaN
# 2014-01-14        NaN        NaN        NaN        NaN        NaN        NaN
# 2014-01-15        NaN        NaN        NaN        NaN        NaN        NaN
# 2014-01-16        NaN        NaN        NaN        NaN        NaN        NaN
#
#             var1(t-3)  var1(t-2)  var1(t-1)  var1(t)
# data
# 2014-01-12        NaN        NaN        NaN      NaN
# 2014-01-13        NaN        NaN        NaN      NaN
# 2014-01-14        NaN        NaN        NaN      NaN
# 2014-01-15        NaN        NaN        NaN      NaN
# 2014-01-16        NaN        NaN        NaN      NaN
#
# [5 rows x 26 columns]

# %%
reframed = reframed[['count', 'week_number', 'weekday', 'var1(t-9)', 
                     'var1(t-7)', 'var1(t-5)', 'var1(t-2)', 'var1(t-1)','var1(t)']]
reframed = reframed[10:]

# %%
values = reframed.values
train = values[:805, :]
test = values[805:, :]
train_X, train_y = train[:,:-1], train[:, -1]
test_X, test_y = test[:,:-1], test[:, -1]

# %%
# 转换为3维
train_X = train_X.reshape((train_X.shape[0],1,train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0],1,test_X.shape[1]))

# %%
# sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
# K.set_session(sess)
model = Sequential()
model.add(LSTM(128, input_shape=(train_X.shape[1],train_X.shape[2]),
               activation='relu',return_sequences=False))
model.add(Dropout(0.5))
model.add(Dense(64,activation='relu',kernel_initializer='random_uniform',
                bias_initializer='zeros'))
model.add(Dropout(0.5))
# model.add(LSTM(16,activation='relu',return_sequences=False))
model.add(Dense(16,kernel_initializer='random_uniform',
                bias_initializer='zeros'))
model.add(Dense(1))
# model.add(Activation("linear"))
opt = keras.optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=None, decay=0.0)
# 805/805 [==============================] - 0s 80us/step - loss: 14.1090 - val_loss: 12.9906
# Epoch 37/50
# 805/805 [==============================] - 0s 79us/step - loss: 14.4552 - val_loss: 12.8839
# Epoch 38/50
# 805/805 [==============================] - 0s 79us/step - loss: 14.1751 - val_loss: 12.6181
# Epoch 39/50
# 805/805 [==============================] - 0s 98us/step - loss: 14.7906 - val_loss: 12.6849
# Epoch 40/50
# 805/805 [==============================] - 0s 94us/step - loss: 14.6282 - val_loss: 12.5903
# Epoch 41/50
# 805/805 [==============================] - 0s 92us/step - loss: 14.3061 - val_loss: 12.7202
# Epoch 42/50
# 805/805 [==============================] - 0s 91us/step - loss: 14.0780 - val_loss: 12.6897
# Epoch 43/50
# 805/805 [==============================] - 0s 92us/step - loss: 14.0969 - val_loss: 12.7007
# Epoch 44/50
# 805/805 [==============================] - 0s 93us/step - loss: 13.7747 - val_loss: 12.8712
# Epoch 45/50
# 805/805 [==============================] - 0s 91us/step - loss: 14.0888 - val_loss: 12.5968
# Epoch 46/50
# 805/805 [==============================] - 0s 92us/step - loss: 14.3857 - val_loss: 12.6318
# Epoch 47/50
# 805/805 [==============================] - 0s 77us/step - loss: 14.2780 - val_loss: 12.7742
# Epoch 48/50
# 805/805 [==============================] - 0s 77us/step - loss: 13.8827 - val_loss: 12.5729
# Epoch 49/50
# 805/805 [==============================] - 0s 76us/step - loss: 14.1048 - val_loss: 12.6104
# Epoch 50/50
# 805/805 [==============================] - 0s 76us/step - loss: 14.2627 - val_loss: 12.5487

# %%
from matplotlib import pyplot
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
# from compiler.ast import flatten
prediction = model.predict(test_X).flatten()
pre_list = prediction.tolist()
true_list = test_y.tolist()

# %%
restore_pre = []
# restore_pre.append(-3.5254192 + pre_list_svr[0])
for i in range(len(pre_list)):
    true = pre_list[i] + before_diff[i]
    restore_pre.append(true)
print(restore_pre[:10])
# Out:
# [3.1320816757278447, 37.886345910400394, 46.12631120132446, 43.56025890762329, 41.143002981567385, 35.13993612495422, 27.467398620605465, 2.1855465992942813, 45.08092701391602, 27.730185527038575]

# %% [markdown]
# 对真实值还原，再与data[805:], 验证还原原始数据正确

# %%
restore_true = []
for i in range(len(true_list)):
    true = true_list[i] + before_diff[i]
    restore_true.append(true)
print(restore_true[:10])
# Out:
# [2.1917315000000004, 40.1299915, 48.297196, 37.748775, 31.280784, 86.86975100000001, 2.655299999999997, 3.5128689000000004, 24.613574999999997, 40.364395]

# %%
data[805:][:10]
# Out:
#             scaled_money
# data
# 2016-04-17      2.191731
# 2016-04-18     40.129990
# 2016-04-19     48.297195
# 2016-04-20     37.748775
# 2016-04-21     31.280785
# 2016-04-22     86.869750
# 2016-04-23      2.655307
# 2016-04-24      3.512869
# 2016-04-25     24.613575
# 2016-04-26     40.364395

# %% [markdown]
# 画出还原后的数据的真实值和预测值图像

# %%
# 发现好多预测值小于0，对于小于0的数据用5代替
for i in range(len(restore_pre)):
    if restore_pre[i] < 0:
        restore_pre[i] = 5

# %%
plt.plot(restore_true[:100])
plt.plot(restore_pre[:100], color='red')
plt.show()

# %%
# 误差定义
error = sum(list(map(lambda x:abs(abs(x[0] - x[1])/(x[1])), zip(restore_pre,restore_true))))
# error = sum(list(map(lambda x: x[0]-x[1], zip(pre_list,true_list))))
print('error',float((error/len(restore_pre))*100),'%')
# Out:
# ('error', 130.8799514665074, '%')

# %%
# 覆盖率计算
count = 0
for i in range(len(restore_pre)):
    if restore_pre[i] > restore_true[i]:
        count += 1
ratio = count*1.0/len(restore_pre)
print("覆盖率为： %.4f"% ratio)
# Out:
# 覆盖率为： 0.5231
